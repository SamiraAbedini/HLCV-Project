# %%
# !pip install -q lmdb opencv-python pillow matplotlib numpy pandas six kaggle tabulate
# !git clone https://github.com/qcf-568/DocTamper.git
# %cd DocTamper

# %%
# !pip install -q kaggle

import os
from pathlib import Path
import getpass

token = getpass.getpass("Paste your Kaggle API token here: ")

kaggle_dir = Path.home() / ".kaggle"
kaggle_dir.mkdir(parents=True, exist_ok=True)

token_path = kaggle_dir / "access_token"
token_path.write_text(token)

os.chmod(token_path, 0o600)

print("Kaggle token saved successfully.")

# !kaggle competitions list

# %%
# !mkdir -p ../data/doctamper_download
# !mkdir -p ../data/doctamper_data
# !kaggle datasets download -d dinmkeljiame/doctamper -p ../data/doctamper_download

# %%
import os
import getpass

os.environ["DOCTAMPER_PASSWORD"] = getpass.getpass("Paste the DocTamper unzip password from the authors' email: ")
print("Password stored temporarily.")

# %%
# !unzip -P "$DOCTAMPER_PASSWORD" -o ../data/doctamper_download/doctamper.zip -d ../data/doctamper_data
